# %%
import pymongo
from pymongo import MongoClient

client = MongoClient("mongodb+srv://imdb_adt:imdb_adt@cluster0.rcvxgzc.mongodb.net/")

# %%
movie_database = client.get_database(name='Moviedatabase')

# %%
movie_database
# Out:
# Database(MongoClient(host=['ac-gakyrft-shard-00-01.rcvxgzc.mongodb.net:27017', 'ac-gakyrft-shard-00-02.rcvxgzc.mongodb.net:27017', 'ac-gakyrft-shard-00-00.rcvxgzc.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-11n0hw-shard-0', tls=True), 'Moviedatabase')

# %%
movie_collection = movie_database.Moviedatabase

# %%
movie_collection
# Out:
# Collection(Database(MongoClient(host=['ac-gakyrft-shard-00-01.rcvxgzc.mongodb.net:27017', 'ac-gakyrft-shard-00-02.rcvxgzc.mongodb.net:27017', 'ac-gakyrft-shard-00-00.rcvxgzc.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-11n0hw-shard-0', tls=True), 'Moviedatabase'), 'Moviedatabase')

# %%
movie_collection.insert_many([
    {
        "MovieName":"12_Angry_Men_1957",
        "reviews": [
            {"date":'s','title':'t','review':'r','rating':2,'link':'https'},
            {"date":'s','title':'t','review':'r','rating':2,'link':'https'},
            {"date":'s','title':'t','review':'r','rating':2,'link':'https'},
            {"date":'s','title':'t','review':'r','rating':2,'link':'https'},
        ],
        "wikipedia": {"plot":"Hello there"}
    }
])
# Out:
# InsertManyResult([ObjectId('6552abefbabc1c542ccea25e')], acknowledged=True)

# %%
import pandas as pd
import os
movie_df = pd.read_csv(os.path.join("movie_reviews","12_Angry_Men_1957.csv"))
for idx,row in movie_df.iterrows():
    print(idx,row)
    break
# Out:
# 0 review_date                                         7 February 2022
# review_title                   Juror #4 is why this is a great film
# review_comment    The film is considered a classic because of th...
# review_rating                                                  10.0
# review_link       https://www.imdb.com/review/rw7843884/?ref_=tt...
# Name: 0, dtype: object

# %%
movie_df.columns
# Out:
# Index(['review_date', 'review_title', 'review_comment', 'review_rating',
#        'review_link'],
#       dtype='object')

# %%
from insert import main_insert

main_insert()

# %%
import pandas as pd
import os

def insert_format(movie_name:str,review_folder:str="movie_reviews",wikipedia_folder:str="wikipedia_data"):
    movie_dict = {}
    csv_name = movie_name+".csv"
    txt_name = movie_name+".txt"
    movie_df = pd.read_csv(os.path.join(review_folder,csv_name))
    fill_values = {'review_date':'', 'review_title':'', 'review_comment':'','review_rating':-1,'review_link':''}
    movie_df.fillna(fill_values,inplace=True)
    with open(os.path.join(wikipedia_folder,txt_name), 'r') as f:
        wiki_data = f.read()
    movie_dict.update({"MovieName":movie_name})
    movie_dict.update({"reviews":[]})
    for _,row in movie_df.iterrows():
        movie_dict['reviews'].append({
            "date":row['review_date'],
            "title":row['review_title'],
            "review":row['review_comment'],
            "rating":row['review_rating'],
            "link":row['review_link']}
        )
    movie_dict.update({"wikipedia":{"plot":wiki_data}})
    return movie_dict

# %%
angry_men = insert_format("12_Angry_Men_1957")

# %%
movie_collection.insert_one(angry_men)
# Out:
# InsertOneResult(ObjectId('6552b3adbabc1c542ccea25f'), acknowledged=True)

# %%
angry_men
# Out:
# {'MovieName': '12_Angry_Men_1957',
#  'reviews': [{'date': '7 February 2022',
#    'title': 'Juror #4 is why this is a great film',
# ...

# %%
import re

sentence = "Hello there 4564 and I am 64567 plust the 4523345, 1 out of 2 found this helpful"

# Define the regular expression pattern
pattern = r'(\d+)\s*out\s*of\s*(\d+)'

# Use re.search to find the match in the sentence
match = re.search(pattern, sentence)

if match:
    # Extract the two numerical figures
    first_number = match.group(1)
    second_number = match.group(2)

    print("First number:", first_number)
    print("Second number:", second_number)
else:
    print("No match found")
# Out:
# First number: 1
# Second number: 2

# %%
from datetime import datetime

date_string = "27 April 2008"
date_format = "%d %B %Y"

# Convert the string to a datetime object
converted_date = datetime.strptime(date_string, date_format)
print(converted_date.date())
print(converted_date)
# Out:
# 2008-04-27
# 2008-04-27 00:00:00

# %%
type(converted_date.date())
# Out:
# datetime.date

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 11, 14, 19, 54, 12, 262299)

# %%
from insert import insert_format

d = insert_format("Parasite_2019")
# Out:
# [{'MovieName': 'Parasite_2019', 'reviews': {'date': datetime.datetime(2019, 7, 5, 0, 0), 'title': 'One of the best films of this decade', 'comment': 'I am remarkably stingy with my 10 10 ratings I ll be the first person to acknowledge this Of the roughly 2600 titles I ve rated on here only 34 have a 10 Parasite is one of them If this isn t a masterpiece then I don t know what is I m going to keep it vague on the plot front because I didn t know anything about it going in and was really excited to see it progress and unfold in satisfying unexpected ways What I will say is that this film more than just about any other I ve seen put me through so many different emotional states during its 132 minute runtime and did so without ever feeling muddled or tonally inconsistent Parts of this movie were hilarious Parts were heartbreaking Other parts were insanely suspenseful I m honestly not sure if I ve felt this close to the edge of my seat since the final season of Breaking Bad way back in 20
# ...

# %%
d[-1]
# Out:
# {'MovieName': 'Parasite_2019',
# ...
